# %% [markdown]
# # Introduction

# %% [markdown]
# In this tutorial, you will try to implement a passive reinforcement learning agent. However, to better understand the algorithm itself, it is best to assume nothing about the environment. Therefore, I won't tell you how the environment works, nor the effects of your actions.
#
# The only thing that you will know is that the observations provided by the environment are in the form of numpy arrays with two values $(a, b)$ where $a$ is an integer between $0$ and $55$, $b$ is an integer between $0$ and $36$. Terminal flag can be *True* or *False*. Your actions are integeres between $0$, and $37$. The reward is an integer between $0$ and $55$. I also tell you that the environment is steady and does not change drastically, so the discount factor should be close to $1$.
#
# We will use the *gymnasium* library (formerly the *OpenAI Gym library*). The first thing we need to do is to download the environment, import the library, and register the environment within the library.

# %%
# !pip install gymnasium
# !pip install matplotlib

import urllib.request
urllib.request.urlretrieve("https://cw.fel.cvut.cz/wiki/_media/courses/smu/game.py", "game.py")

# %matplotlib inline
from game import *
import gymnasium as gym
from gymnasium.envs.registration import register
from gymnasium import wrappers
import numpy as np

register(
    id='smu-rl-env-v1',
    entry_point='game:SMUTutorialEnv'
)
envsimple = gym.make('smu-rl-env-v1')
# Out:
# Requirement already satisfied: gymnasium in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from gymnasium) (2.4.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from gymnasium) (0.0.4)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gavul\desktop\cvut_programming\ctu_smu\lab02\venv_lab02\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# c:\Users\gavul\Desktop\cvut_programming\CTU_SMU\lab02\venv_lab02\Lib\site-packages\gymnasium\envs\registration.py:480: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes']
#   logger.warn(

# %% [markdown]
# <h1> The passive reinforcement learning agent using temporal difference. </h1>
#
# First, we will implement an agent with a fixed learning rate. We will use a fixed strategy and observe how well it performs. The policy with $20\,\%$ selects action $37$. Otherwise, the agent randomly picks a number; all have the same probability. The policy is not deterministic in this case; however, TD-learning can be shown that it works anyway.

# %%
def policy(observation):
    if observation[1] > 27 or np.random.random() < 0.2:
        return 37
    return np.random.randint(0, 37)

# %% [markdown]
# For now, we will use a fixed learning rate to see how the policy performs.

# %%
alpha = 0.1

# %% [markdown]
# Now we can implement the agent. The TD method follows the pseudocode below:
#
# ---
#
# <ol> <li>   Repeat (for each episode):
#  <ol>
#  <li>   Initialize $s$ as the start state.
#  <li>   Repeat (for each step):
#  <ol>
#    <li> $a \gets$ action given by $\pi$ in $s$
#    <li> Take action $a$; observe reward $r$, and the next state $s'$
#    <li> $\widehat{U}(s) \gets \widehat{U}(s) + \alpha \left( r + \gamma \widehat{U}(s') - \widehat{U}(s) \right)$
#    <li> $s \gets s'$
#   </ol>
#   <li> until $s$ is terminal
#   </ol>
# </ol>
#
# ---
#
#
#
# The pseudocode is taken from <a href="http://www.incompleteideas.net/book/the-book.html">Sutton, Barto book, figure 6.1</a>.

# %% [markdown]
# First, we need to initialize the number of episodes and discount factor. Pick your own values.

# %%
number_of_epochs = 1000000 # TODO pick your own number and discount factor
# discount_factor = 0.99
# discount_factor = 0.7 # Seems good
discount_factor = 0.7

# %% [markdown]
# The template for the code is provided and is similar to the one you have in your project. Modify the code as handy. Documentation is available on <a href="https://gymnasium.farama.org/">https://gymnasium.farama.org/</a>. Method <code>env.reset</code> will start a new episode, method <code>env.step</code> implements a single interaction with the environment. Now is the time to implement the TD learning agent.

# %%
# this is the OpenAI Gym environment, you will access
env = envsimple
# TODO : here, store utility function estimates, i.e., a dictionary, an array or anything else
U = None

for i in range(number_of_epochs):
    observation, _ = env.reset()
    print(observation)
    terminal = False

    while (not terminal):
      observation, reward, terminal, _, _ = env.step(policy(observation))
    # TODO your code here
    # in each step you will need to call method env.step() with the action given
    # by the policy() method above

    #env.render() will show you the state of the environment
# Out:
# Streaming output truncated to the last 5000 lines.
# [ 8 25]
# [ 1 19]
# [ 1 17]
# [ 3 12]
# [9 6]
# [9 7]
# [2 9]
# [ 7 24]
# [3 9]
# [ 1 25]
# [9 3]
# [ 8 18]
# [ 3 28]
# [ 7 34]
# [ 1 18]
# [ 1 29]
# [ 9 32]
# [ 2 34]
# [ 8 15]
# [1 6]
# [7 9]
# [2 6]
# [ 1 20]
# [ 4 13]
# [ 1 26]
# [7 3]
# [ 8 16]
# [ 1 24]
# [ 2 14]
# [9 5]
# [9 3]
# [2 0]
# [1 4]
# [ 4 33]
# [ 9 14]
# [ 2 22]
# [ 3 33]
# [ 4 13]
# [ 8 13]
# [ 6 13]
# [ 6 26]
# [ 7 16]
# [ 2 23]
# [ 3 11]
# [ 3 19]
# [9 5]
# [ 6 33]
# [ 2 12]
# [ 2 27]
# [ 3 11]
# [ 8 20]
# [6 9]
# [ 9 32]
# [7 1]
# [2 1]
# [ 3 24]
# [ 9 34]
# [ 1 30]
# [ 1 11]
# [ 3 23]
# [3 6]
# [ 5 10]
# [ 9 31]
# [7 8]
# [ 1 11]
# [1 5]
# [ 5 17]
# [ 1 32]
# [ 8 14]
# [ 5 36]
# [6 1]
# [ 7 19]
# [ 2 14]
# [1 1]
# [ 5 21]
# [ 2 32]
# [ 6 32]
# [2 8]
# [ 8 34]
# [ 8 14]
# [ 5 17]
# [9 0]
# [7 6]
# [ 2 34]
# [ 7 21]
# [ 1 23]
# [8 9]
# [ 2 26]
# [ 3 16]
# [ 6 17]
# [ 6 14]
# [1 7]
# [ 2 25]
# [ 5 19]
# [ 8 34]
# [ 1 30]
# [5 0]
# [ 7 16]
# [8 6]
# [ 2 24]
# [ 4 36]
# [ 1 23]
# [ 8 28]
# [ 5 15]
# [ 4 28]
# [ 5 23]
# [ 1 35]
# [ 9 17]
# [9 5]
# [3 0]
# [ 7 34]
# [2 2]
# [ 3 14]
# [ 8 10]
# [ 6 14]
# [ 9 23]
# [ 4 21]
# [ 2 15]
# [4 4]
# [ 3 32]
# [ 2 25]
# [ 3 18]
# [ 5 17]
# [ 6 21]
# [8 4]
# [ 2 25]
# [ 8 18]
# [ 2 29]
# [ 6 21]
# [ 8 27]
# [ 7 31]
# [ 9 17]
# [ 3 11]
# [ 3 34]
# [ 3 28]
# [ 1 27]
# [ 5 30]
# [ 5 31]
# [ 9 23]
# [ 6 25]
# [ 7 29]
# [8 6]
# [ 6 24]
# [ 7 17]
# [5 7]
# [ 1 20]
# [4 4]
# [ 9 26]
# [ 1 13]
# [5 0]
# [ 5 27]
# [ 8 36]
# [ 6 29]
# [ 8 10]
# [ 8 10]
# [8 3]
# [ 6 19]
# [ 3 14]
# [ 8 19]
# [ 1 20]
# [1 0]
# [ 6 26]
# [ 4 24]
# [1 9]
# [ 1 32]
# [ 3 29]
# [ 3 34]
# [ 6 17]
# [ 9 27]
# [ 8 12]
# [6 0]
# [8 0]
# [4 8]
# [3 5]
# [ 4 25]
# [8 0]
# [ 8 12]
# [ 1 35]
# [ 9 10]
# [ 4 29]
# [ 8 29]
# [ 4 36]
# [8 9]
# [ 4 10]
# [ 9 11]
# [7 8]
# [7 2]
# [4 0]
# [ 6 10]
# [ 3 31]
# [ 8 25]
# [ 3 13]
# [ 8 27]
# [2 4]
# [3 7]
# [ 8 29]
# [ 3 19]
# [ 6 30]
# [4 4]
# [5 7]
# [ 6 32]
# [6 9]
# [ 4 12]
# [7 2]
# [ 7 35]
# [ 2 21]
# [3 2]
# [ 4 14]
# [ 7 34]
# [ 4 14]
# [ 7 25]
# [ 4 25]
# [ 1 28]
# [ 6 33]
# [9 9]
# [ 9 19]
# [3 9]
# [ 5 34]
# [3 5]
# [ 3 14]
# [2 8]
# [ 5 20]
# [4 9]
# [6 4]
# [ 4 19]
# [7 1]
# [ 4 15]
# [ 1 18]
# [ 1 15]
# [ 9 34]
# [2 9]
# [ 8 29]
# [ 2 32]
# [5 1]
# [ 2 24]
# [ 8 13]
# [ 1 18]
# [ 1 29]
# [ 4 27]
# [ 2 13]
# [ 5 29]
# [ 3 18]
# [ 9 22]
# [ 1 23]
# [ 2 25]
# [ 3 24]
# [6 1]
# [ 9 23]
# [9 6]
# [ 6 16]
# [ 4 21]
# [ 8 22]
# [ 6 14]
# [ 3 33]
# [ 5 35]
# [ 8 17]
# [ 3 33]
# [ 7 28]
# [ 9 32]
# [5 0]
# [ 4 21]
# [ 2 36]
# [ 8 21]
# [ 1 20]
# [ 2 21]
# [1 5]
# [ 2 18]
# [ 8 35]
# [ 3 26]
# [ 2 29]
# [5 1]
# [ 7 21]
# [ 8 25]
# [ 4 13]
# [ 3 35]
# [ 2 23]
# [ 4 15]
# [ 7 23]
# [ 6 23]
# [4 3]
# [2 5]
# [ 4 21]
# [ 5 32]
# [8 4]
# [ 9 24]
# [ 8 26]
# [ 6 16]
# [ 2 19]
# [ 1 29]
# [ 5 35]
# [7 7]
# [4 4]
# [ 7 24]
# [9 6]
# [2 2]
# [ 4 19]
# [ 4 24]
# [5 0]
# [ 4 22]
# [ 8 36]
# [ 1 35]
# [3 0]
# [ 7 36]
# [ 5 36]
# [ 2 15]
# [7 5]
# [ 6 15]
# [ 6 32]
# [5 0]
# [ 4 18]
# [ 7 29]
# [ 4 19]
# [ 3 10]
# [ 4 18]
# [ 5 16]
# [ 4 12]
# [ 2 13]
# [ 8 33]
# [ 3 20]
# [ 1 18]
# [ 6 35]
# [ 6 36]
# [ 5 20]
# [ 2 27]
# [ 4 24]
# [ 7 21]
# [ 5 27]
# [ 1 34]
# [ 3 20]
# [ 4 33]
# [ 8 10]
# [ 6 18]
# [ 2 11]
# [ 4 13]
# [1 1]
# [ 9 12]
# [ 9 16]
# [ 7 25]
# [ 8 22]
# [ 1 35]
# [7 3]
# [ 4 12]
# [9 6]
# [ 7 27]
# [ 3 20]
# [ 8 16]
# [4 4]
# [ 7 34]
# [ 4 27]
# [ 3 33]
# [ 8 22]
# [ 2 16]
# [ 8 28]
# [6 0]
# [ 9 32]
# [ 8 27]
# [ 3 36]
# [ 6 33]
# [ 8 12]
# [ 9 36]
# [ 6 23]
# [ 7 34]
# [ 9 31]
# [4 1]
# [7 2]
# [ 3 15]
# [ 6 27]
# [ 7 13]
# [ 6 32]
# [9 7]
# [1 6]
# [ 2 10]
# [1 3]
# [ 4 12]
# [5 6]
# [ 1 27]
# [ 1 22]
# [ 7 25]
# [ 5 13]
# [ 7 18]
# [ 5 24]
# [ 4 34]
# [ 1 31]
# [ 5 15]
# [4 1]
# [ 4 17]
# [ 7 35]
# [9 8]
# [ 9 22]
# [9 0]
# [ 6 21]
# [ 2 28]
# [ 9 29]
# [9 7]
# [ 6 31]
# [ 7 11]
# [ 9 10]
# [ 4 36]
# [1 8]
# [ 1 32]
# [ 6 35]
# [ 5 32]
# [ 7 10]
# [ 3 28]
# [ 6 32]
# [ 5 20]
# [ 5 22]
# [ 3 17]
# [ 8 20]
# [ 9 25]
# [ 5 21]
# [ 7 19]
# [ 9 35]
# [ 6 35]
# [1 9]
# [ 3 30]
# [ 2 12]
# [ 1 15]
# [ 4 17]
# [4 6]
# [6 8]
# [ 3 16]
# [ 2 27]
# [ 3 22]
# [ 8 29]
# [ 9 15]
# [ 9 16]
# [3 2]
# [ 7 21]
# [ 9 35]
# [ 8 26]
# [ 5 35]
# [ 2 26]
# [ 5 10]
# [ 5 25]
# [ 3 26]
# [ 4 22]
# [ 4 20]
# [ 8 36]
# [ 3 15]
# [ 1 30]
# [7 8]
# [8 4]
# [ 1 18]
# [ 3 32]
# [ 6 26]
# [ 1 30]
# [4 6]
# [ 7 32]
# [2 9]
# [ 3 33]
# [ 2 14]
# [1 9]
# [ 3 12]
# [ 4 21]
# [ 1 20]
# [3 3]
# [ 7 14]
# [7 2]
# [2 2]
# [ 6 16]
# [ 6 19]
# [7 3]
# [ 5 21]
# [ 1 19]
# [9 8]
# [ 6 20]
# [ 4 14]
# [ 4 14]
# [3 2]
# [ 6 21]
# [ 2 24]
# [ 3 32]
# [7 0]
# [ 1 18]
# [ 8 29]
# [9 1]
# [7 4]
# [ 2 12]
# [ 4 10]
# [ 2 26]
# [ 9 31]
# [ 4 29]
# [8 2]
# [ 5 29]
# [8 1]
# [ 6 23]
# [ 9 25]
# [ 2 22]
# [ 9 36]
# [ 4 16]
# [ 5 11]
# [ 3 28]
# [ 3 35]
# [ 3 14]
# [4 3]
# [ 9 10]
# [ 8 18]
# [ 3 22]
# [ 9 36]
# [ 4 14]
# [4 3]
# [ 4 16]
# [ 9 33]
# [ 5 16]
# [2 0]
# [ 4 25]
# [ 5 29]
# [ 7 24]
# [ 3 32]
# [ 5 26]
# [ 1 17]
# [1 2]
# [ 9 21]
# [ 4 21]
# [ 6 23]
# [ 3 11]
# [ 3 32]
# [1 6]
# [8 8]
# [ 1 22]
# [ 1 29]
# [ 3 10]
# [2 0]
# [ 4 26]
# [ 6 26]
# [ 2 21]
# [9 8]
# [ 6 26]
# [ 8 16]
# [ 6 27]
# [ 6 32]
# [ 6 16]
# [ 1 19]
# [ 5 26]
# [ 1 24]
# [ 2 10]
# [ 6 17]
# [2 2]
# [ 6 20]
# [ 7 26]
# [ 3 13]
# [ 3 26]
# [ 6 36]
# [ 8 25]
# [ 3 17]
# [9 8]
# [ 9 27]
# [8 6]
# [5 7]
# [ 7 18]
# [7 7]
# [ 1 24]
# [2 9]
# [2 2]
# [ 2 32]
# [ 5 15]
# [ 4 18]
# [ 7 21]
# [ 5 36]
# [ 8 16]
# [ 8 24]
# [1 9]
# [ 6 27]
# [ 8 27]
# [ 6 17]
# [ 3 19]
# [ 5 35]
# [ 3 19]
# [ 9 21]
# [1 4]
# [ 7 20]
# [9 1]
# [8 5]
# [5 0]
# [ 3 22]
# [8 7]
# [ 5 31]
# [4 2]
# [ 4 28]
# [2 8]
# [ 3 20]
# [ 8 24]
# [ 1 20]
# [6 6]
# [ 5 10]
# [1 1]
# [ 9 20]
# [ 4 16]
# [6 5]
# [6 7]
# [2 4]
# [9 8]
# [ 2 28]
# [ 1 27]
# [ 2 10]
# [ 5 25]
# [ 7 31]
# [4 8]
# [8 2]
# [ 9 15]
# [ 1 21]
# [ 3 31]
# [9 5]
# [ 2 19]
# [ 9 34]
# [1 6]
# [ 3 11]
# [ 6 36]
# [8 4]
# [ 2 24]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-156/2218269573.py in <cell line: 0>()
#       6 for i in range(number_of_epochs):
#       7     observation, _ = env.reset()
# ----> 8     print(observation)
#       9     terminal = False
#      10
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1667         return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
#    1668
# -> 1669     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#    1670
#    1671
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     760         return "[]"
#     761
# --> 762     return _array2string(a, options, separator, prefix)
#     763
#     764
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in wrapper(self, *args, **kwargs)
#     532             repr_running.add(key)
#     533             try:
# --> 534                 return f(self, *args, **kwargs)
#     535             finally:
#     536                 repr_running.discard(key)
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in _array2string(a, options, separator, prefix)
#     558
#     559     # find the right formatting function for the array
# --> 560     format_function = _get_format_function(data, **options)
#     561
#     562     # skip over "["
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in _get_format_function(data, **options)
#     486             return formatdict['timedelta']()
#     487         else:
# --> 488             return formatdict['int']()
#     489     elif issubclass(dtypeobj, _nt.floating):
#     490         if issubclass(dtypeobj, _nt.longdouble):
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in <lambda>()
#     429     formatdict = {
#     430         'bool': lambda: BoolFormat(data),
# --> 431         'int': lambda: IntegerFormat(data, sign),
#     432         'float': lambda: FloatingFormat(
#     433             data, precision, floatmode, suppress, sign, legacy=legacy),
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in __init__(self, data, sign)
#    1259         if data.size > 0:
#    1260             data_max = np.max(data)
# -> 1261             data_min = np.min(data)
#    1262             data_max_str_len = len(str(data_max))
#    1263             if sign == ' ' and data_min < 0:
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in min(a, axis, out, keepdims, initial, where)
#    3040     6
#    3041     """
# -> 3042     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    3043                           keepdims=keepdims, initial=initial, where=where)
#    3044
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
# this is the OpenAI Gym environment, you will access
env = envsimple
# TODO : here, store utility function estimates, i.e., a dictionary, an array or anything else
U = None

for i in range(number_of_epochs):
    observation, _ = env.reset()
    print(observation)
    terminal = False

    while (not terminal):
      observation, reward, terminal, _, _ = env.step(policy(observation))
    # TODO your code here
    # in each step you will need to call method env.step() with the action given
    # by the policy() method above

    #env.render() will show you the state of the environment
# Out:
# [ 6 15]
#
# [ 5 24]
#
# [ 2 13]
#
# [ 2 21]
#
# [5 5]
#
# [7 9]
#
# [9 1]
#
# [ 2 29]
#
# [ 5 33]
#
# [ 7 36]

# %%
# this is the OpenAI Gym environment, you will access
env = envsimple
# TODO : here, store utility function estimates, i.e., a dictionary, an array or anything else
U = {}

for i in range(number_of_epochs):
    observation, _ = env.reset()
    # print(observation)
    terminal = False

    while (not terminal):
      current_state = tuple(observation)  # Convert numpy array to tuple

      if current_state not in U:
        U[current_state] = 0

      observation, reward, terminal, _, _ = env.step(policy(observation))
      next_state = tuple(observation)  # Convert numpy array to tuple

      if next_state not in U:
        U[next_state] = 0

      U[current_state] = U.get(current_state) + alpha * (reward + discount_factor * U.get(next_state) - U.get(current_state))

    # TODO your code here
    # in each step you will need to call method env.step() with the action given
    # by the policy() method above

    #env.render() will show you the state of the environment

# %%
print(U)
# Out:
# {(np.int64(5), np.int64(11)): 0.45, (np.int64(5), np.int64(26)): 0, (np.int64(6), np.int64(25)): 0.0, (np.int64(7), np.int64(36)): 0.7000000000000001, (np.int64(7), np.int64(28)): 0.7000000000000001, (np.int64(2), np.int64(17)): 0.0, (np.int64(1), np.int64(33)): 0.1, (np.int64(1), np.int64(12)): 0, (np.int64(5), np.int64(23)): 0.0, (np.int64(6), np.int64(7)): 0.0, (np.int64(7), np.int64(5)): 0.7000000000000001, (np.int64(7), np.int64(24)): 0.0, (np.int64(5), np.int64(9)): 0.0, (np.int64(4), np.int64(27)): 0.0, (np.int64(5), np.int64(28)): 0.5, (np.int64(5), np.int64(12)): 0, (np.int64(8), np.int64(16)): 0.8, (np.int64(1), np.int64(15)): 0.0, (np.int64(0), np.int64(0)): 0, (np.int64(2), np.int64(20)): 0.2, (np.int64(2), np.int64(13)): 0, (np.int64(6), np.int64(22)): 0.0, (np.int64(7), np.int64(20)): 0.0, (np.int64(6), np.int64(0)): 0.0, (np.int64(6), np.int64(14)): 0.0, (np.int64(8), np.int64(8)): 0.8, (np.int64(8), np.int64(29)): 0, (np.int64(7), np.int64(0)): 0.0, (np.int64(8), np.int64(27)): 0.0, (np.int64(7), np.int64(1)): 0}

# %%
print(U.get((5, 11)))
# Out:
# 0.45

# %%
print(U.get((10, 1)))
# Out:
# None

# %% [markdown]
# <h1>Convergence of utility values</h1>
#
# Now when the code works, we need to test it. Copy the code to the cell below and check whether the utility values converged.
#
# *   In each iteration, store the value of the non-terminal state $(10,1)$ to field <code>Us101</code>.
# *   Store the maximum update made to $\widehat{U}$ in a single iteration to field <code>maxDelta</code>.

# %%
env = envsimple
# TODO : here, store utility function estimates, i.e., a dictionary, an array or anything else
U = None
Us101 = np.zeros(number_of_epochs)
maxDelta = np.zeros(number_of_epochs)

for i in range(number_of_epochs):
    observation, _ = env.reset()
    # TODO your code here
    #env.render()
    maxDelta[i] = None # TODO : store the maximum update to U
    Us101[i] = None # TODO :  store the value of a state (you can pick a different one if you want)

# %%
env = envsimple
# TODO : here, store utility function estimates, i.e., a dictionary, an array or anything else
U = {}
Us101 = np.zeros(number_of_epochs)
maxDelta = np.zeros(number_of_epochs)

for i in range(number_of_epochs):
    # print(i)
    observation, _ = env.reset()
    terminal = False
    deltas = []

    # TODO your code here
    while (not terminal):
      current_state = tuple(observation)  # Convert numpy array to tuple

      if current_state not in U:
        U[current_state] = 0

      current_state_value = U.get(current_state)
      observation, reward, terminal, _, _ = env.step(policy(observation))
      next_state = tuple(observation)  # Convert numpy array to tuple

      if next_state not in U:
        U[next_state] = 0

      U[current_state] = U.get(current_state) + alpha * (reward + discount_factor * U.get(next_state) - U.get(current_state))
      deltas.append(abs(U[current_state] - current_state_value))

    #env.render()
    maxDelta[i] = max(deltas) # TODO : store the maximum update to U
    Us101[i] = U.get((10, 1)) # TODO :  store the value of a state (you can pick a different one if you want)

# %%
Us101
# Out:
# array([       nan,        nan,        nan, ..., 7.49665254, 7.49665254,
#        7.49665254])

# %% [markdown]
# Now we will render the utility over time. We will use the <code>matplotlib</code> library and the following utility method.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_series(arr, fileName = None):
    plt.plot(arr)
    if fileName is not None:
        plt.savefig(fileName)

# %% [markdown]
# Now, plot the stored $\widehat{U}$ value history for your selected state.

# %%
plot_series(Us101)
# put a name of a file as a second parameter if you want to save the figure

# %% [markdown]
# We would expect the value to be around $10$. The result may depend on the value of the learning rate. If you get a plot like the following one, the values did not converge.
# <center>
#
#   ![not_converged.png](data:image/png;base64,...)
#
# </center>
# However, if your results look like the one below, the value for this state is correct. The values don't converge since we set a constant learning rate. The average, however, converges.
#
# <center>
#
# ![converged.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# The value of maximum update to the state utility function is explanatory as well.

# %%
plot_series(maxDelta)

# %% [markdown]
# The plot should look like the one below.
# <center>
#
#   ![delta_constant_alpha.png](data:image/png;base64,...)
#
# </center>
# The utility function did not converge. However, <b>the average values </b> of $\widehat{U}$ converge. (optionally check yourself)

# %%
# TODO: optionally check that the average values of $U(s)$ converge

# %% [markdown]
# <h1> Decrease the learning rate </h1>
# If your state utility function converged in the last section, good job. If not, we know the solution from the lecture - the value of learning rate $\alpha$ should be decreasing with the number of trials. More specifically, with the number of visits to the current state. In the last plot, the maximum change was approximately constant over time. As a result, the utility values oscillate.
#
# Therefore, copy the code from the last section to the cell below and choose some function so that the value of learning rate $\alpha$ decreases with the number of visits of a state. Formally, it must hold that
# $$ \sum_{k=0}^\infty \alpha_k = \infty $$
# and
# $$ \sum_{k=0}^\infty \alpha_k^2 < \infty, $$
# i.e., the sum of $\alpha_k$ diverges and sum of $\alpha_k^2$ converges. The first condition is needed so that learning can overcome arbitrarily large initial error; the second one eliminates shattering around the value, which we have seen in the last section.
#
# Answer the following question yourself: Why should be learning rate different for each state?

# %%
env = envsimple
U = {} # TODO : define utility function
Ns = {} # TODO : this time you have to store the number of visits of each state
Us101 = np.zeros(number_of_epochs)
maxDelta = np.zeros(number_of_epochs)

for i in range(number_of_epochs):
    observation, _ = env.reset()
    # TODO your code here
    terminal = False
    deltas = []

    # TODO your code here
    while (not terminal):
      # Convert numpy array to tuple - observation is numpy array which cannot be used as key
      current_state = tuple(observation)

      # 1. Set initial values for state that is visited for the first time
      if current_state not in U:
        U[current_state] = 0
        Ns[current_state] = 0

      # 2. Increase number of visits for state s
      Ns[current_state] += 1

      current_state_value = U.get(current_state)

      # 3. Apply action and get next information
      observation, reward, terminal, _, _ = env.step(policy(observation))

      next_state = tuple(observation)  # Convert numpy array to tuple

      # 4. Set initial values for next state s'
      if next_state not in U:
        U[next_state] = 0
        Ns[next_state] = 0

      # 5. Compute alpha - learning rate
      # alpha = 1 / Ns[current_state]
      alpha = 2 / (1 + Ns[current_state])

      # 6. Compute value for current state
      U[current_state] = U.get(current_state) + alpha * (reward + discount_factor * U.get(next_state) - U.get(current_state))

      # 7. Compute and save update in U value in current iteration
      deltas.append(abs(U[current_state] - current_state_value))

    #env.render()
    maxDelta[i] = max(deltas) # TODO : store the maximum update to U(s)
    Us101[i] = U.get((10, 1)) # TODO :  store the value of a state (you can pick a different one)

# %%
U[(5, 17)]
# Out:
# 5.481147733474661

# %%
Ns[(5, 17)]
# Out:
# 7486

# %%
env = envsimple
U = {} # TODO : define utility function
Ns = {} # TODO : this time you have to store the number of visits of each state
Us101 = np.zeros(number_of_epochs)
maxDelta = np.zeros(number_of_epochs)

for i in range(number_of_epochs):
    observation, _ = env.reset()
    # TODO your code here
    #env.render()
    maxDelta[i] = None # TODO : store the maximum update to U(s)
    Us101[i] = None # TODO :  store the value of a state (you can pick a different one)

# %% [markdown]
# Rerun your code, this time with $\alpha$ decreasing with the number of visits of a state. Check the result.

# %%
plot_series(Us101)

# %% [markdown]
# If your state utility function looks like the one below, you won because the values converged. If not, try again.
# <center>
#
#   ![converged_decreasing_alpha.png](data:image/png;base64,...)
#
# </center>
# Hint: <span style="color:white">In AIMA, they use $$\alpha = \frac{c}{c - 1 + \mbox{number of visits}}$$ for a constant $c$

# %% [markdown]
# Plot the maximum change in the state utility function.

# %%
plot_series(maxDelta)

# %% [markdown]
# We see that the update is decreasing (as expected).
# <center>
#
#   ![delta_decreasing_alpha.png](data:image/png;base64,...)
#
# </center>
# However, in this case, the result is not nice as the maximum is not robust statistics. Why do we see such high peaks even after $1 000 000$ games played? Compare with the following picture.
# <center>
#
#    ![delta_decreasing_alpha_last_year.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# <h1> Further work </h1>
#
# If you got to this point, could continue yourself without detailed instructions. Here are some ideas of what you may want to do in the remaining time:
# <ul>
#   <li> Go to <code>game.py</code> file and change the number of states. Does the TD method scale? What is the maximum number of states?
#   <li> On <a href="https://gymnasium.farama.org/">https://gymnasium.farama.org/</a> you may find plenty of environments. Pick one and pick one of the strategies that were submitted to the page. Then estimate the state utility function of the strategy.
#   <li> Implement the First/Every visit Monte Carlo and compare it to the TD.
#   <li> Whatever you are interested in ...
# </ul>
